# %%
import pandas as pd
import sys
import os
from tabulate import tabulate

# %%
def _readReport():
    global GlobalVar
    GlobalVar.reportDf = pd.read_excel("WeeklyReport-V1.0-2019.09.30-TonyOu.xlsx", header = 0)
    for dateColumn in GlobalVar.dateMetadata:
        GlobalVar.reportDf[dateColumn] = GlobalVar.reportDf[dateColumn].dt.date

def _showBrief():
    global GlobalVar
    displayMetadata = list()
    for i in range(len(GlobalVar.displayColumns)):
        displayMetadata.append(GlobalVar.metadata[GlobalVar.displayColumns[i]])
    print(tabulate(GlobalVar.reportDf[displayMetadata], headers='keys', tablefmt='psql'))

def _saveXlsx():
    global GlobalVar
    GlobalVar.reportDf.to_excel(GlobalVar.fileName, index = False)
    
def saveExcel():
    _saveXlsx()
    
def displayAll():
    global GlobalVar
    print(tabulate(GlobalVar.reportDf, headers='keys', tablefmt='psql'))
    
def addNewRow():
    global GlobalVar
    newDataDict = dict()
    for key in GlobalVar.metadata:
        if key not in GlobalVar.constMetadata:
            newDataDict[key] = input(key + ": ")
        else:
            newDataDict[key] = ""
    GlobalVar.reportDf = GlobalVar.reportDf.append(newDataDict, ignore_index=True)
    _showBrief()
    
def _controller():
    global GlobalVar
    showFlag = True
    action = None
    _showBrief()
    while(True):
        action = input("To do? ").lower().strip()
        if action in GlobalVar.functionDict:
            try:
                GlobalVar.functionDict[action]()
            except:
                print("Unexpected error:", sys.exc_info()[0])
        else:
            print("Unknow function")
def initializeApp():
    _readReport()
    _controller()

class GlobalVar():
    reportDf = None
    metadata =  ['A_DATE', 'ITEM', 'OA_DESC', 'AP', 'SKILL', 'SITE', 'DUE_DATE', 'COMPLET_D', 'OWNER', 'IT_STATUS', 'OA_NO', 'PROGRAM', 'W_HOUR', 'REMARK', 'PROG_CNT', 'OA_STATUS']
    constMetadata = ['A_DATE', 'ITEM']
    dateMetadata = ['DUE_DATE', 'COMPLET_D']
    displayColumns = [2, 12, 13]
    functionDict = {"new": addNewRow, "all": displayAll, "save": saveExcel}
    fileName = "WeeklyReport-V1.0-2019.09.30-TonyOu.xlsx"

# %%
initializeApp()
# Out:
# +----+----------------------------------------------------------+----------+----------------------------+
# |    | OA_DESC                                                  |   W_HOUR | REMARK                     |
# |----+----------------------------------------------------------+----------+----------------------------|
# |  0 | 製作git server與app進度ppt                               |      0.5 | 製作git server與app進度ppt |
# |  1 | 架設git server於伺服器                                   |      2.5 | 架設git server於伺服器     |
# |  2 | 連結app到google firebase                                 |      4   | 連結app到google firebase   |
# |  3 | 研究git相關開發流程                                      |      4   | git flow與github flow      |
# |  4 | FIFO系統簡介與架構介紹課程                               |      1   | 由Kangi上課                |
# |  5 | 二部9月份部會                                            |      2   | 二部9月份部會              |
# |  6 | [32 Bits 轉 64 Bits]-TP訂餐系統 ASP 轉 JSP- 報表統計模組 |     22   | 設計台北午晚餐主管簽核單   |
# |  7 | [32 Bits 轉 64 Bits]-TP訂餐系統 ASP 轉 JSP- 報表統計模組 |      4   | 設計台北午晚餐薪資代扣表   |
# +----+----------------------------------------------------------+----------+----------------------------+
# To do? all
# +----+----------+--------+----------------------------------------------------------+----------+---------+--------+------------+-------------+---------+-------------+-----------+---------------------+----------+----------------------------+------------+-------------+
# |    |   A_DATE |   ITEM | OA_DESC                                                  | AP       | SKILL   | SITE   | DUE_DATE   | COMPLET_D   | OWNER   | IT_STATUS   | OA_NO     | PROGRAM             |   W_HOUR | REMARK                     |   PROG_CNT | OA_STATUS   |
# |----+----------+--------+----------------------------------------------------------+----------+---------+--------+------------+-------------+---------+-------------+-----------+---------------------+----------+----------------------------+------------+-------------|
# |  0 | 20190923 |      1 | 製作git server與app進度ppt                               | Other    | Check   | nan    | 2019-09-23 | 2019-09-23  | Tony    | nan         | nan       | nan                 |      0.5 | 製作git server與app進度ppt |          0 | nan         |
# |  1 | 20190923 |      2 | 架設git server於伺服器                                   | Other    | Check   | nan    | 2019-09-23 | 2019-09-23  | Tony    | nan         | nan       | nan                 |      2.5 | 架設git server於伺服器     |          0 | nan         |
# |  2 | 20190923 |      3 | 連結app到google firebase                                 | Other    | Check   | nan    | 2019-09-23 | 2019-09-23  | Tony    | nan         | nan       | nan                 |      4   | 連結app到google firebase   |          0 | nan         |
# |  3 | 20190923 |      4 | 研究git相關開發流程                                      | Study    | Check   | nan    | 2019-09-27 | 2019-09-27  | Tony    | nan         | nan       | nan                 |      4   | git flow與github flow      |          0 | nan         |
# |  4 | 20190923 |      5 | FIFO系統簡介與架構介紹課程                               | Training | Check   | nan    | 2019-09-27 | 2019-09-27  | Tony    | nan         | nan       | nan                 |      1   | 由Kangi上課                |          0 | nan         |
# |  5 | 20190923 |      6 | 二部9月份部會                                            | Meeting  | Check   | nan    | 2019-09-27 | 2019-09-27  | Tony    | nan         | nan       | nan                 |      2   | 二部9月份部會              |          0 | nan         |
# |  6 | 20190923 |      7 | [32 Bits 轉 64 Bits]-TP訂餐系統 ASP 轉 JSP- 報表統計模組 | TPMW     | jsp     | UG TW  | 2019-09-26 | 2019-09-26  | Tony    | 設計完成    | SAI106362 | admin_report4.jsp,  |     22   | 設計台北午晚餐主管簽核單   |          0 | Done        |
# |    |          |        |                                                          |          |         |        |            |             |         |             |           | admin_report4_s.jsp |          |                            |            |             |
# |  7 | 20190923 |      8 | [32 Bits 轉 64 Bits]-TP訂餐系統 ASP 轉 JSP- 報表統計模組 | TPMW     | jsp     | UG TW  | 2019-09-26 | 2019-09-26  | Tony    | 設計完成    | SAI106362 | admin_report5.jsp,  |      4   | 設計台北午晚餐薪資代扣表   |          0 | Done        |
# |    |          |        |                                                          |          |         |        |            |             |         |             |           | admin_report5_s.jsp |          |                            |            |             |
# +----+----------+--------+----------------------------------------------------------+----------+---------+--------+------------+-------------+---------+-------------+-----------+---------------------+----------+----------------------------+------------+-------------+
# To do? new
# OA_DESC: f
# AP: f
# SKILL: f
# SITE: f
# DUE_DATE: f
# COMPLET_D: f
# OWNER: f
# IT_STATUS: f
# OA_NO: f
# PROGRAM: f
# W_HOUR: f
# REMARK: f
# PROG_CNT: f
# OA_STATUS: f
# +----+----------------------------------------------------------+----------+----------------------------+
# |    | OA_DESC                                                  | W_HOUR   | REMARK                     |
# |----+----------------------------------------------------------+----------+----------------------------|
# |  0 | 製作git server與app進度ppt                               | 0.5      | 製作git server與app進度ppt |
# |  1 | 架設git server於伺服器                                   | 2.5      | 架設git server於伺服器     |
# |  2 | 連結app到google firebase                                 | 4.0      | 連結app到google firebase   |
# |  3 | 研究git相關開發流程                                      | 4.0      | git flow與github flow      |
# |  4 | FIFO系統簡介與架構介紹課程                               | 1.0      | 由Kangi上課                |
# |  5 | 二部9月份部會                                            | 2.0      | 二部9月份部會              |
# |  6 | [32 Bits 轉 64 Bits]-TP訂餐系統 ASP 轉 JSP- 報表統計模組 | 22.0     | 設計台北午晚餐主管簽核單   |
# |  7 | [32 Bits 轉 64 Bits]-TP訂餐系統 ASP 轉 JSP- 報表統計模組 | 4.0      | 設計台北午晚餐薪資代扣表   |
# |  8 | f                                                        | f        | f                          |
# +----+----------------------------------------------------------+----------+----------------------------+
# To do? all
# +----+----------+--------+----------------------------------------------------------+----------+---------+--------+------------+-------------+---------+-------------+-----------+---------------------+----------+----------------------------+------------+-------------+
# |    | A_DATE   | ITEM   | OA_DESC                                                  | AP       | SKILL   | SITE   | DUE_DATE   | COMPLET_D   | OWNER   | IT_STATUS   | OA_NO     | PROGRAM             | W_HOUR   | REMARK                     | PROG_CNT   | OA_STATUS   |
# |----+----------+--------+----------------------------------------------------------+----------+---------+--------+------------+-------------+---------+-------------+-----------+---------------------+----------+----------------------------+------------+-------------|
# |  0 | 20190923 | 1      | 製作git server與app進度ppt                               | Other    | Check   | nan    | 2019-09-23 | 2019-09-23  | Tony    | nan         | nan       | nan                 | 0.5      | 製作git server與app進度ppt | 0          | nan         |
# |  1 | 20190923 | 2      | 架設git server於伺服器                                   | Other    | Check   | nan    | 2019-09-23 | 2019-09-23  | Tony    | nan         | nan       | nan                 | 2.5      | 架設git server於伺服器     | 0          | nan         |
# |  2 | 20190923 | 3      | 連結app到google firebase                                 | Other    | Check   | nan    | 2019-09-23 | 2019-09-23  | Tony    | nan         | nan       | nan                 | 4.0      | 連結app到google firebase   | 0          | nan         |
# |  3 | 20190923 | 4      | 研究git相關開發流程                                      | Study    | Check   | nan    | 2019-09-27 | 2019-09-27  | Tony    | nan         | nan       | nan                 | 4.0      | git flow與github flow      | 0          | nan         |
# |  4 | 20190923 | 5      | FIFO系統簡介與架構介紹課程                               | Training | Check   | nan    | 2019-09-27 | 2019-09-27  | Tony    | nan         | nan       | nan                 | 1.0      | 由Kangi上課                | 0          | nan         |
# |  5 | 20190923 | 6      | 二部9月份部會                                            | Meeting  | Check   | nan    | 2019-09-27 | 2019-09-27  | Tony    | nan         | nan       | nan                 | 2.0      | 二部9月份部會              | 0          | nan         |
# |  6 | 20190923 | 7      | [32 Bits 轉 64 Bits]-TP訂餐系統 ASP 轉 JSP- 報表統計模組 | TPMW     | jsp     | UG TW  | 2019-09-26 | 2019-09-26  | Tony    | 設計完成    | SAI106362 | admin_report4.jsp,  | 22.0     | 設計台北午晚餐主管簽核單   | 0          | Done        |
# |    |          |        |                                                          |          |         |        |            |             |         |             |           | admin_report4_s.jsp |          |                            |            |             |
# |  7 | 20190923 | 8      | [32 Bits 轉 64 Bits]-TP訂餐系統 ASP 轉 JSP- 報表統計模組 | TPMW     | jsp     | UG TW  | 2019-09-26 | 2019-09-26  | Tony    | 設計完成    | SAI106362 | admin_report5.jsp,  | 4.0      | 設計台北午晚餐薪資代扣表   | 0          | Done        |
# |    |          |        |                                                          |          |         |        |            |             |         |             |           | admin_report5_s.jsp |          |                            |            |             |
# |  8 |          |        | f                                                        | f        | f       | f      | f          | f           | f       | f           | f         | f                   | f        | f                          | f          | f           |
# +----+----------+--------+----------------------------------------------------------+----------+---------+--------+------------+-------------+---------+-------------+-----------+---------------------+----------+----------------------------+------------+-------------+
# To do? f
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Anthony\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# c:\Users\Anthony\Anaconda3\lib\site-packages\jupyter_client\session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# c:\Users\Anthony\Anaconda3\lib\site-packages\zmq\sugar\socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# c:\Users\Anthony\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-1f0c98a5307e> in <module>
# ----> 1 initializeApp()
#
# <ipython-input-31-fbfb13d09903> in initializeApp()
#      50 def initializeApp():
#      51     _readReport()
# ---> 52     _controller()
#      53
#      54 class GlobalVar():
#
# <ipython-input-31-fbfb13d09903> in _controller()
#      40     _showBrief()
#      41     while(True):
# ---> 42         action = input("To do? ").lower().strip()
#      43         if action in GlobalVar.functionDict:
#      44             try:
#
# c:\Users\Anthony\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858             self._parent_ident,
#     859             self._parent_header,
# --> 860             password=False,
#     861         )
#     862
#
# c:\Users\Anthony\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     888             except KeyboardInterrupt:
#     889                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 890                 raise KeyboardInterrupt
#     891             else:
#     892                 break
#
# KeyboardInterrupt:
